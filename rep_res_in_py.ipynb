# %% [markdown]
# <a href="https://colab.research.google.com/github/mfernandes61/reprod_res_source/blob/main/rep_res_in_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# This is **some** text.
# # Big heading
# ## Is this heading bigger?
# ### Even smaller
# #### smaller still
# This also __bold__.
# What is *this*?
#
# ```
# print("hello")
# ```
# ~~This text is irrelevant~~ \
# Some more text
#
# This <u>underlined</u>

# %% [markdown]
# You can underline text by using HTML tags in your Markdown.
# Like <u>this</u>.

# %% [markdown]
# We can embed LaTeX (The mathematical typesetting language) into our Markdown like this:
# The quadratic formula is $-b \pm \sqrt{b^2 - 4ac} \over 2a$
#
#
# $\int_0^1 \frac{dx}{e^x} =  \frac{e-1}{e}$
#
#
# > example of an Indented block
#
# - [ ] unchecked box
# - [x] checked box

# %% [markdown]
# $$\require{mhchem}$$
#
# $\ce{Na2SO4 ->[H2O] Na+ + SO4^2-}$

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace (0, 5, 100) # generates evenly spaces numbers
plt.plot(x, x, label='linear')
plt.plot(x, x ** 2, label='quadratic')
plt.plot(x, x ** 3, label='cubic')
plt.xlabel('x label')
plt.ylabel('y label')
plt.title("Three plots")

plt.legend();
plt. show()
